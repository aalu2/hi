# %%
True and 1 / 0 and False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-da046ec8e9df> in <module>
# ----> 1 True and 1 / 0 and False
#
# ZeroDivisionError: division by zero

# %%
True or 1 / 0 or False
# Out:
# True

# %%
True and 0
# Out:
# 0

# %%
False or 1
# Out:
# 1

# %%
 1 and 3 and 6 and 10 and 15
# Out:
# 15

# %%
 0 or False or 2 or 1 / 0
# Out:
# 2

# %%
def welcome():
   print('Welcome to', end=' ')
   return 'Hello'

def CS250():
  print('CS250')
  return 'Python'

print(welcome(), CS250())
# Out:
# Welcome to CS250
# Hello Python

# %%
x = 6
def foo1(x):
  print(x) 
  
def foo2(x):
       y = x
       x = 7
       print(x)

y = foo1(x)
foo2(x)
y =foo1(8)
# Out:
# 6
# 7
# 8

# %%
def cake(batter): 
    return batter 
def pan(x, y): 
      y = y + 20 
      return x(y) 
pan(print, 10)
# Out:
# 30

# %%
def print_sub(a, b):
  print('sub') 
  return a - b
def print_mul(x, y):
    print('mul') 
    return x * y 
a = print_sub(print_mul(4, 504), 2)
print(a)
# Out:
# mul
# sub
# 2014

# %%
x = 10 
def foo(): 
  return x
def bar(x): 
  return x
def foobar(new_value): 
  x = new_value 
  y = x + 1 
  return x
foo() 
bar(5) 
foobar(20) 
print (x) 
print (y)
# Out:
# 10
# 11

# %%
a = 1 
def b(b): 
    return a + b 
a = b(a) 
a = b(a)

# %%
def sub(a, b): 
  sub = add 
  return a - b
add = sub 
sub = min 
print(add(2, sub(2, 3)))
# Out:
# 0

# %%
def sum(a,b):
  return(a + abs(b))
